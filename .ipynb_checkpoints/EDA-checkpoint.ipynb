# %%
#pip install --upgrade numexpr
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
import warnings
warnings.filterwarnings('ignore')

# %%
#%run C:/Users/prana/Documents/NCI/PythonWorkSpace/functionsMaster.ipynb

# %%
# Read the data 
file_path="../Stats_CA/Data/mlr7.csv"

# define a function to read csv file 
def read_csv_to_dataframe(file_path):
    try:
        df = pd.read_csv(file_path)
        return df
    except Exception as e:
        print(f"Error reading the CSV file: {e}")
        return None
    


df=read_csv_to_dataframe(file_path)

df.head()
# Out:
#               y         x1          x2 x3
# 0  15116.994383  48.330231  203.906565  B
# 1  16889.339729  48.450240  207.498762  B
# 2  14170.002472  49.675754  197.181472  C
# 3  18189.584499  58.266768  197.408598  B
# 4  15788.441002  50.890988  200.350295  A

# %%
# check for unique values,datatype and missing values 

# function to print dtypes, count unique and missing values.
def show_missing(df):
    """Return a Pandas dataframe describing the contents of a source dataframe including missing values."""
    
    variables = []
    dtypes = []
    count = []
    unique = []
    missing = []
    pc_missing = []
    
    for item in df.columns:
        variables.append(item)
        dtypes.append(df[item].dtype)
        count.append(len(df[item]))
        unique.append(len(df[item].unique()))
        missing.append(df[item].isna().sum())
        pc_missing.append(round((df[item].isna().sum() / len(df[item])) * 100, 2))

    output = pd.DataFrame({
        'variable': variables, 
        'dtype': dtypes,
        'count': count,
        'unique': unique,
        'missing': missing, 
        'pc_missing': pc_missing
    })    
        
    return output

    
show_missing(df)
# Out:
#   variable    dtype  count  unique  missing  pc_missing
# 0        y  float64   1000    1000        0         0.0
# 1       x1  float64   1000    1000        0         0.0
# 2       x2  float64   1000    1000        0         0.0
# 3       x3   object   1000       3        0         0.0

# %%
# statistical deistribution of the dataframe round to two decimals
print(df.describe().round(2))
# Out:
#               y       x1       x2
# count   1000.00  1000.00  1000.00
# mean   15393.87    49.96   200.05
# std     1641.53     3.93     4.11
# min     8437.54    29.93   188.39
# 25%    14633.52    48.71   197.24
# 50%    15433.67    50.10   200.24
# 75%    16275.00    51.33   202.75
# max    22741.07    71.64   212.92

# %%
# locate unique values in x
df['x3'].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
# https://plotly.com/python/distplot/
# histogram of 
fig = px.histogram(df, x="x1", y="y", color="x3", marginal="rug",
                   hover_data=df.columns)
# all three of these worked
fig.show(renderer='iframe')
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_39.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_39.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.histogram(df, x="x2", y="y", color="x3", marginal="rug",
                   hover_data=df.columns)
# all three of these worked
fig.show(renderer='iframe')
fig.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_40.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_40.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# extract all numerial columns 

def get_numericalFields(df):
    numerical_df = df.select_dtypes(include=['number'])
    return numerical_df


df_num=get_numericalFields(df)

# %%
# check for outliers using boxplot 
np.random.seed(10)

# define the fiture size
fig = plt.figure(figsize =(10, 7))

# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot(df_num)

# show plot
plt.show()

# %%
# visualise the districution of numerical variables 
# %matplotlib inline
df.hist(column=['x1','x2','y'],figsize=(12,4))
# Out:
# array([[<Axes: title={'center': 'x1'}>, <Axes: title={'center': 'x2'}>],
#        [<Axes: title={'center': 'y'}>, <Axes: >]], dtype=object)

# %%
import plotly.express as px
fig1= px.histogram(df, 
                   x="x1",
                   nbins=20,
                   color="x3",
                   title="Histogram of x1")
fig2= px.histogram(df, 
                   x="x2", 
                   nbins=20,
                   color="x3",
                   title="Histogram of x2")
fig3= px.histogram(df, 
                   x="y", 
                   nbins=20,
                   color="x3",
                   title="Histogram of y")

# %%
# "Histogram of x1"
fig1.show(renderer='iframe')
fig1.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_44.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_44.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# "Histogram of x2"
fig2.show(renderer='iframe')
fig2.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_45.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_45.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# "Histogram of x1"
fig3.show(renderer='iframe')
fig3.show(renderer='iframe_connected')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_46.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_46.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Correlation Heatmap 
heat_map_corr(df_num)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %%
sns.histplot(df['x2'], kde=True, bins=20, color='grey', kde_kws={'bw_adjust': 0.5})
plt.title('Histogram of x2')
plt.xlabel('Values of x2')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['x1'], kde=True, bins=20, color='grey', kde_kws={'bw_adjust': 0.5})
# Out:
# <Axes: xlabel='x1', ylabel='Count'>

# %%
sns.histplot(df['x2'], kde=True, bins=20, color='green')
# Out:
# <Axes: xlabel='x2', ylabel='Count'>
